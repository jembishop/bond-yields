# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("bond_yields.csv", parse_dates=True, index_col="ISIN Code")
df
# Out:
#               Lowest Accepted Yield  Average Yield  Highest Accepted Yield  \
# ISIN Code
# GB00B3G75552                  0.400       0.443114                   0.459
# GB00B3G9C724                  0.430       0.491670                   0.510
# GB00B3GD5425                  0.479       0.529363                   0.550
# GB00B3G7CD26                  0.400       0.441294                   0.450
# GB00B3G9LM06                  0.440       0.486693                   0.500
# ...                             ...            ...                     ...
# GB00BXRD4888                 -0.020       0.041957                   0.090
# GB00BXRFP702                  0.004       0.042684                   0.064
# GB00BDXDBT27                 -0.160      -0.095500                  -0.040
# GB00BDXFCR34                  0.210       0.273446                   0.374
# GB00BDXGST09                  0.338       0.406363                   0.429
#
#               Average Rate of Discount (%)  \
# ...

# %%
df.set_index(["Maturity (Months)", "Date"])["Highest Accepted Yield"].unstack(level=0).plot(
    sharex=False, figsize=(20, 10))
